# %% [markdown]
# ## IMPORTING OF PYTHON LIBRARIES AND DATASET

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loan dataset in pandas dataframe
df=pd.read_csv("loan_data_set.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ## EXPLORATION OF RAW DATA

# %%
# total rows and colmns
df.shape
# Out:
# (614, 13)

# %%
#head
df.head(60)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate           NaN
# 12  LP001028    Male     Yes          2      Graduate            No
# ...

# %%
#tail
df.tail(60)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 554  LP002789    Male     Yes          0      Graduate            No
# 555  LP002792    Male     Yes          1      Graduate            No
# 556  LP002794  Female      No          0      Graduate            No
# 557  LP002795    Male     Yes         3+      Graduate           Yes
# 558  LP002798    Male     Yes          0      Graduate            No
# 559  LP002804  Female     Yes          0      Graduate            No
# 560  LP002807    Male     Yes          2  Not Graduate            No
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 562  LP002820    Male     Yes          0      Graduate            No
# 563  LP002821    Male      No          0  Not Graduate           Yes
# 564  LP002832    Male     Yes          2      Graduate            No
# 565  LP002833    Male     Yes          0  Not Graduate            No
# 566  LP002836    Male      No          0      Graduate            No
# ...

# %%
# columns name
# Loan_ID (unique + not null)
# Gender
# Married
#Dependents	
#Education	
#Self_Employed	
#ApplicantIncome	
#CoapplicantIncome	
#LoanAmount	
#Loan_Amount_Term
#Credit_History	
#Property_Area	
#Loan_Status

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# ### Removing Duplicates

# %%
df["Loan_ID"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Handling Missing Values

# %%
# total missing values of each column
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#total missing values
(df.isnull().sum()).sum()
# Out:
# 149

# %%
# 1.Gender Column
df["Gender"].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df["Gender"].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
df["Gender"]=df["Gender"].replace(np.nan,("Male"))

# %%
# 2.Married column
df["Married"].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df["Married"].mode()
# Out:
# 0    Yes
# Name: Married, dtype: object

# %%
df["Married"]=df["Married"].replace(np.nan,("Yes"))

# %%
# Dependents colunn
print(df["Dependents"].unique())
print()
print(df["Dependents"].mode())
# Out:
# ['0' '1' '2' '3+' nan]
#
# 0    0
# Name: Dependents, dtype: object

# %%
df["Dependents"]=df["Dependents"].replace(np.nan,("0"))

# %%
#replacing value
df["Dependents"]=df["Dependents"].replace({"3+":"3"}) #df["Dependents"].replace("3+",3,inplace=True)

# %%
# self employed column
print(df["Self_Employed"].unique())
print()
print(df["Self_Employed"].mode())
# Out:
# ['No' 'Yes' nan]
#
# 0    No
# Name: Self_Employed, dtype: object

# %%
df["Self_Employed"]=df["Self_Employed"].replace(np.nan,("No"))

# %%
# Loan Amount Column
print(df["LoanAmount"].unique())
print()
print(df["LoanAmount"].median())
# Out:
# [ nan 128.  66. 120. 141. 267.  95. 158. 168. 349.  70. 109. 200. 114.
#   17. 125. 100.  76. 133. 115. 104. 315. 116. 112. 151. 191. 122. 110.
#   35. 201.  74. 106. 320. 144. 184.  80.  47.  75. 134.  96.  88.  44.
#  286.  97. 135. 180.  99. 165. 258. 126. 312. 136. 172.  81. 187. 113.
#  176. 130. 111. 167. 265.  50. 210. 175. 131. 188.  25. 137. 160. 225.
#  216.  94. 139. 152. 118. 185. 154.  85. 259. 194.  93. 370. 182. 650.
#  102. 290.  84. 242. 129.  30. 244. 600. 255.  98. 275. 121.  63. 700.
#   87. 101. 495.  67.  73. 260. 108.  58.  48. 164. 170.  83.  90. 166.
#  124.  55.  59. 127. 214. 240.  72.  60. 138.  42. 280. 140. 155. 123.
#  279. 192. 304. 330. 150. 207. 436.  78.  54.  89. 143. 105. 132. 480.
#   56. 159. 300. 376. 117.  71. 490. 173.  46. 228. 308. 236. 570. 380.
#  296. 156. 103.  45.  65.  53. 360.  62. 218. 178. 239. 405. 148. 190.
#  149. 153. 162. 230.  86. 234. 246. 500. 186. 119. 107. 209. 208. 243.
# ...

# %%
df["LoanAmount"]=df["LoanAmount"].replace(np.nan,("129"))

# %%
# Loan_Amout_Term
print(df["Loan_Amount_Term"].unique())
print()
print(df["Loan_Amount_Term"].mode())
# Out:
# [360. 120. 240.  nan 180.  60. 300. 480.  36.  84.  12.]
#
# 0    360.0
# Name: Loan_Amount_Term, dtype: float64

# %%
print(df["Loan_Amount_Term"].unique())
# Out:
# [360. 120. 240.  nan 180.  60. 300. 480.  36.  84.  12.]

# %%
df["Loan_Amount_Term"]=df["Loan_Amount_Term"].replace(np.nan,("360"))

# %%
#Credit_History
print(df["Credit_History"].unique())
print()
print(df["Credit_History"].mode())
# Out:
# [ 1.  0. nan]
#
# 0    1.0
# Name: Credit_History, dtype: float64

# %%
df["Credit_History"]=df["Credit_History"].replace(np.nan,(1))

# %% [markdown]
# ### Changing Dtype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    object
#  9   Loan_Amount_Term   614 non-null    object
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 62.5+ KB

# %%
# changing dtype
df["Dependents"]=df["Dependents"].astype(int)
df["CoapplicantIncome"]=df["CoapplicantIncome"].astype(int)
df["LoanAmount"]=df["LoanAmount"].astype(int)
df["Loan_Amount_Term"]=df["Loan_Amount_Term"].astype(int)
df["Credit_History"]=df["Credit_History"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    int32
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    int32
#  8   LoanAmount         614 non-null    int32
#  9   Loan_Amount_Term   614 non-null    int32
#  10  Credit_History     614 non-null    int32
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: int32(5), int64(1), object(7)
# memory usage: 50.5+ KB

# %% [markdown]
# ### Column Transformation

# %%
# replacing column name
df.rename(columns={'Married':'Marital_Status'},inplace=True)
df.rename(columns={'Loan_Amount_Term':'Loan_Amount_Term(years)'},inplace=True)

# %%
df["Marital_Status"]=df["Marital_Status"].replace({"Yes":"Married"})
df["Marital_Status"]=df["Marital_Status"].replace({"No":"Unmarried"})

# %%
df['Loan_Amount_Term(years)']=df['Loan_Amount_Term(years)'].replace({12:1})
df['Loan_Amount_Term(years)']=df['Loan_Amount_Term(years)'].replace({36:3})
df['Loan_Amount_Term(years)']=df['Loan_Amount_Term(years)'].replace({60:5})
df['Loan_Amount_Term(years)']=df['Loan_Amount_Term(years)'].replace({87:7})
df['Loan_Amount_Term(years)']=df['Loan_Amount_Term(years)'].replace({120:10})
df['Loan_Amount_Term(years)']=df['Loan_Amount_Term(years)'].replace({180:15})
df['Loan_Amount_Term(years)']=df['Loan_Amount_Term(years)'].replace({240:20})
df['Loan_Amount_Term(years)']=df['Loan_Amount_Term(years)'].replace({300:25})
df['Loan_Amount_Term(years)']=df['Loan_Amount_Term(years)'].replace({360:30})
df['Loan_Amount_Term(years)']=df['Loan_Amount_Term(years)'].replace({480:40})

# %% [markdown]
# ## cleaned data

# %%
df
# Out:
#       Loan_ID  Gender Marital_Status  Dependents     Education Self_Employed  \
# 0    LP001002    Male      Unmarried           0      Graduate            No
# 1    LP001003    Male        Married           1      Graduate            No
# 2    LP001005    Male        Married           0      Graduate           Yes
# 3    LP001006    Male        Married           0  Not Graduate            No
# 4    LP001008    Male      Unmarried           0      Graduate            No
# ..        ...     ...            ...         ...           ...           ...
# 609  LP002978  Female      Unmarried           0      Graduate            No
# 610  LP002979    Male        Married           3      Graduate            No
# 611  LP002983    Male        Married           1      Graduate            No
# 612  LP002984    Male        Married           2      Graduate            No
# 613  LP002990  Female      Unmarried           0      Graduate           Yes
#
# ...

# %%
df.describe()
# Out:
#        Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count  614.000000       614.000000          614.00000  614.000000
# mean     0.744300      5403.459283         1621.24430  145.788274
# std      1.009623      6109.041673         2926.24876   84.099864
# min      0.000000       150.000000            0.00000    9.000000
# 25%      0.000000      2877.500000            0.00000  100.250000
# 50%      0.000000      3812.500000         1188.50000  129.000000
# 75%      1.000000      5795.000000         2297.25000  164.750000
# max      3.000000     81000.000000        41667.00000  700.000000
#
#        Loan_Amount_Term(years)  Credit_History
# count               614.000000      614.000000
# mean                 29.035831        0.855049
# std                   6.754518        0.352339
# min                   1.000000        0.000000
# 25%                  30.000000        1.000000
# 50%                  30.000000        1.000000
# ...

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %%
gp=df.groupby(["Loan_Status","Marital_Status","Gender"]).agg({"Gender":"count"})
print(gp)
# Out:
#                                    Gender
# Loan_Status Marital_Status Gender
# N           Married        Female       8
#                            Male       105
#             Unmarried      Female      29
#                            Male        50
# Y           Married        Female      24
#                            Male       264
#             Unmarried      Female      51
#                            Male        83

# %%
order_1=["Married","Unmarried"]
x= sns.countplot(data = df, x = "Marital_Status",order=order_1, hue = 'Gender')

for bars in x.containers:
    x.bar_label(bars)

# %%
x= sns.countplot(data = df, x ="Gender",hue="Marital_Status",alpha=1)

for bars in x.containers:   
    x.bar_label(bars)

# %%
x= sns.countplot(data = df, x = "Loan_Status", hue = 'Dependents')

for bars in x.containers:
    x.bar_label(bars)

# %%
x= sns.countplot(data = df, x = "Dependents", hue = 'Gender')

for bars in x.containers:
    x.bar_label(bars)

# %%
gp=df.groupby(["Loan_Amount_Term(years)"]).agg({"Loan_Amount_Term(years)":"count"})
gp
# Out:
#                          Loan_Amount_Term(years)
# Loan_Amount_Term(years)
# 1                                              1
# 3                                              2
# 5                                              2
# 10                                             3
# 15                                            44
# 20                                             4
# 25                                            13
# 30                                           526
# 40                                            15
# 84                                             4

# %%
x= sns.countplot(data = df, x ="Loan_Amount_Term(years)",hue="Property_Area")
for bars in x.containers:
    x.bar_label(bars)

# %%
x= sns.countplot(data = df, x ="Loan_Amount_Term(years)",hue="Loan_Amount_Term(years)")
for bars in x.containers:
    x.bar_label(bars)

# %%
x= sns.countplot(data = df, x ="Loan_Status",hue="Loan_Amount_Term(years)")
for bars in x.containers:
    x.bar_label(bars)

# %% [markdown]
# ## Machine Learning Model Of Loan Approval Predicition

# %%
df_1=df.copy()

# %%
df_1
# Out:
#       Loan_ID  Gender Marital_Status  Dependents     Education Self_Employed  \
# 0    LP001002    Male      Unmarried           0      Graduate            No
# 1    LP001003    Male        Married           1      Graduate            No
# 2    LP001005    Male        Married           0      Graduate           Yes
# 3    LP001006    Male        Married           0  Not Graduate            No
# 4    LP001008    Male      Unmarried           0      Graduate            No
# ..        ...     ...            ...         ...           ...           ...
# 609  LP002978  Female      Unmarried           0      Graduate            No
# 610  LP002979    Male        Married           3      Graduate            No
# 611  LP002983    Male        Married           1      Graduate            No
# 612  LP002984    Male        Married           2      Graduate            No
# 613  LP002990  Female      Unmarried           0      Graduate           Yes
#
# ...

# %%
# deleting irrelevent columns
df_1.drop(columns=["Loan_ID"],inplace=True)

# %%
df_1
# Out:
#      Gender Marital_Status  Dependents     Education Self_Employed  \
# 0      Male      Unmarried           0      Graduate            No
# 1      Male        Married           1      Graduate            No
# 2      Male        Married           0      Graduate           Yes
# 3      Male        Married           0  Not Graduate            No
# 4      Male      Unmarried           0      Graduate            No
# ..      ...            ...         ...           ...           ...
# 609  Female      Unmarried           0      Graduate            No
# 610    Male        Married           3      Graduate            No
# 611    Male        Married           1      Graduate            No
# 612    Male        Married           2      Graduate            No
# 613  Female      Unmarried           0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term(years)  \
# 0               5849                  0         129                       30
# ...

# %% [markdown]
# ## Encoding

# %%
# Label Encoding
#columns:Gender,Marital Status,Education,Self_Employed,Loan_Status
from sklearn.preprocessing import LabelEncoder
cols=["Gender","Marital_Status","Dependents","Education","Self_Employed","Property_Area","Loan_Status"]
le=LabelEncoder()
for i in cols:
    df_1[i]=le.fit_transform(df_1[i])

# %%
df_1
# Out:
#      Gender  Marital_Status  Dependents  Education  Self_Employed  \
# 0         1               1           0          0              0
# 1         1               0           1          0              0
# 2         1               0           0          0              1
# 3         1               0           0          1              0
# 4         1               1           0          0              0
# ..      ...             ...         ...        ...            ...
# 609       0               1           0          0              0
# 610       1               0           3          0              0
# 611       1               0           1          0              0
# 612       1               0           2          0              0
# 613       0               1           0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term(years)  \
# 0               5849                  0         129                       30
# ...

# %%
sns.heatmap(df_1.corr())
# Out:
# <Axes: >

# %%
df_1.corr()
# Out:
#                            Gender  Marital_Status  Dependents  Education  \
# Gender                   1.000000       -0.364569    0.172914   0.045364
# Marital_Status          -0.364569        1.000000   -0.334216  -0.012304
# Dependents               0.172914       -0.334216    1.000000   0.055752
# Education                0.045364       -0.012304    0.055752   1.000000
# Self_Employed           -0.000525       -0.004489    0.056798  -0.010383
# ApplicantIncome          0.058809       -0.051708    0.118202  -0.140760
# CoapplicantIncome        0.082912       -0.075947    0.030429  -0.062290
# LoanAmount               0.106964       -0.146584    0.163110  -0.168671
# Loan_Amount_Term(years) -0.071853        0.026043   -0.026882  -0.098035
# Credit_History           0.009170       -0.010938   -0.040160  -0.073658
# Property_Area           -0.025752       -0.004257   -0.000244  -0.065243
# Loan_Status              0.017987       -0.091478    0.010118  -0.085884
#
# ...

# %% [markdown]
# ## Dealing With Outliers

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=df_1)
plt.xticks(rotation=45)
plt.show()

# %%
#ApplicantIncome
sns.boxplot(x="ApplicantIncome",data=df_1)  
plt.grid()
plt.show()

# %%
# IQR
q1=df_1["ApplicantIncome"].quantile(0.25)
q3=df_1["ApplicantIncome"].quantile(0.75)
q1,q3
# Out:
# (2877.5, 5795.0)

# %%
IQR=q3-q1
IQR
# Out:
# 2917.5

# %%
min_range=q1-(1.5*IQR)
max_range=q3+(1.5*IQR)
min_range,max_range
# Out:
# (-1498.75, 10171.25)

# %%
df_1=df_1[df_1["ApplicantIncome"] <=max_range]

# %%
sns.boxplot(x="ApplicantIncome",data=df_1)  
plt.grid()
plt.show()

# %%
#CoapplicantIncome
sns.boxplot(x="CoapplicantIncome",data=df_1)  
plt.grid()
plt.show()

# %%
# IQR
q1_1=df_1["CoapplicantIncome"].quantile(0.25)
q3_1=df_1["CoapplicantIncome"].quantile(0.75)
q1_1,q3_1
# Out:
# (0.0, 2337.0)

# %%
IQR=q3_1-q1_1
IQR
# Out:
# 2337.0

# %%
min_range1=q1_1-(1.5*IQR)
max_range1=q3_1+(1.5*IQR)
min_range1,max_range1
# Out:
# (-3505.5, 5842.5)

# %%
df_1=df_1[df_1["CoapplicantIncome"] <=max_range1]

# %%
sns.boxplot(x="CoapplicantIncome",data=df_1)  
plt.grid()
plt.show()

# %%
df.shape
# Out:
# (614, 13)

# %% [markdown]
# df_1

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=df_1)
plt.xticks(rotation=45)
plt.show()

# %%
df_1.shape
# Out:
# (548, 12)

# %% [markdown]
# ## FEATURE SCALING

# %%
sns.histplot(df_1["ApplicantIncome"],kde=True)
plt.show()

# %%
sns.histplot(df_1["CoapplicantIncome"],kde=True)
plt.show()

# %%
sns.histplot(df_1["LoanAmount"],kde=True)
plt.show()

# %%
sns.histplot(df_1["Loan_Amount_Term(years)"],kde=True)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
df_1["ApplicantIncome"]=sc.fit_transform(df_1[["ApplicantIncome"]])

# %%
df_1["CoapplicantIncome"]=sc.fit_transform(df_1[["CoapplicantIncome"]])

# %%
df_1["LoanAmount"]=sc.fit_transform(df_1[["LoanAmount"]])

# %%
df_1["Loan_Amount_Term(years)"]=sc.fit_transform(df_1[["Loan_Amount_Term(years)"]])

# %% [markdown]
# ## DATASET BALANCING

# %%
plt.figure(figsize=(4,4))
plt.pie(df_1["Loan_Status"].value_counts(),labels=['Yes','No'],autopct='%0.2f')
plt.title("PIE CHART : IMBALANCED LOAN_STATUS")
plt.show()

# %%
import imblearn

# %%
from imblearn.over_sampling import RandomOverSampler
rs=RandomOverSampler()

# %%
a=df_1.iloc[:,:]
b=df_1["Loan_Status"]

# %%
x,y=rs.fit_resample(a,b)

# %%
df_2=x.copy()

# %%
df_2
# Out:
#      Gender  Marital_Status  Dependents  Education  Self_Employed  \
# 0         1               1           0          0              0
# 1         1               0           1          0              0
# 2         1               0           0          0              1
# 3         1               0           0          1              0
# 4         1               1           0          0              0
# ..      ...             ...         ...        ...            ...
# 755       1               0           2          0              1
# 756       1               0           1          0              0
# 757       1               0           1          0              0
# 758       1               0           0          1              0
# 759       1               0           2          0              0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term(years)  \
# 0           0.902588          -0.933094   -0.029860                 0.123329
# ...

# %%
df_2.shape
# Out:
# (760, 12)

# %%
plt.figure(figsize=(4,4))
plt.pie(df_2["Loan_Status"].value_counts(),labels=['Yes','No'],autopct='%0.0f')
plt.title("PIE CHART : BALANCED LOAN_STATUS")
plt.show()

# %% [markdown]
# ## TRAINING AND TESTING

# %%
from sklearn.model_selection import train_test_split

# %%
x=df_2.iloc[:,:-1]
y=df_2["Loan_Status"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3,random_state=42)

# %% [markdown]
# ## MODEL BUILDING

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 75.0

# %%
lr.pred=lr.predict([[0,1,0,0,1,0.238250,-0.933094,0.123329,0.262394,0,1]])
result = lr.pred 
if result == 1:
    print("Approved")
else:
    print("Not_Approved")
# Out:
# Not_Approved
# C:\Users\HP NOTEBOOK\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
